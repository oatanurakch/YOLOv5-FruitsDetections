# %% [markdown]
# <a href="https://colab.research.google.com/github/oatanurakch/YOLOv5-FruitsDetections/blob/main/YoloV5_FruitDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Connect to Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Setup YoloV5**

# %%
# %cd drive/MyDrive/yolov5
# Out:
# /content/drive/MyDrive/yolov5

# %%
# %ls
# Out:
# config.yaml      Dockerfile  models/           runs/           utils/
# CONTRIBUTING.md  export.py   __pycache__/      setup.cfg       val.py
# data/            hubconf.py  README.md         train.py        yolov5m.pt
# detect.py        LICENSE     requirements.txt  tutorial.ipynb  yolov5s.pt

# %%
# %pip install -qr requirements.txt
# Out:
#      |████████████████████████████████| 596 kB 8.1 MB/s

# %%
import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v6.0-266-g07221f1 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.3/166.8 GB disk)

# %% [markdown]
# # **Check Runtime Type**

# %%
! nvidia-smi
# Out:
# Tue Feb 22 07:34:02 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    27W / 250W |      2MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # **Train img 500, batch 32, epochs 300, model yolov5s**

# %%
# !python train.py --img 500 --batch 32 --epochs 300 --data config.yaml --weights yolov5s.pt --cache
# Out:
# ...
# train: weights=yolov5s.pt, cfg=, data=config.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=300, batch_size=32, imgsz=500, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Total 38 (delta 27), reused 27 (delta 27), pack-reused 11
# Unpacking objects: 100% (38/38), done.
# From https://github.com/ultralytics/yolov5
#    07221f1..a936f5f  master     -> origin/master
# github: ⚠️ YOLOv5 is out of date by 10 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# ...

# %% [markdown]
# # **Train img 500, batch 32, epochs 300, model yolov5m**

# %%
# !python train.py --img 500 --batch 32 --epochs 300 --data config.yaml --weights yolov5m.pt --cache
# Out:
# train: weights=yolov5m.pt, cfg=, data=config.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=300, batch_size=32, imgsz=500, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 10 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.0-266-g07221f1 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...

# %% [markdown]
# # **Train img 500, batch 32, epochs 500, model yolov5s**

# %%
# !python train.py --img 500 --batch 32 --epochs 500 --data config.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=config.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=500, batch_size=32, imgsz=500, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Total 12 (delta 3), reused 3 (delta 3), pack-reused 8
# Unpacking objects: 100% (12/12), done.
# Command 'git fetch && git config --get remote.origin.url' timed out after 5 seconds
# YOLOv5 🚀 v6.0-266-g07221f1 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...

# %% [markdown]
# # **Install Module for detect video on YouTube**

# %%
# !pip install pafy

# %%
# !pip install youtube_dl
# Out:
# ...
#      |████████████████████████████████| 1.9 MB 7.8 MB/s
# ...

# %% [markdown]
# # **Detection with Video**

# %%
# !python detect.py --source https://www.youtube.com/watch?v=sA8y-mB6a_0 --weights runs/train/exp3/weights/best.pt --conf 0.4

# %% [markdown]
# # **Detection with Image**

# %%
# !python detect.py --source test_image/ --img 500 --weights runs/train/exp5/weights/best.pt --conf 0.6
# Out:
# detect: weights=['runs/train/exp3/weights/best.pt'], source=test_image/, data=data/coco128.yaml, imgsz=[400, 400], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-266-g07221f1 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# WARNING: --img-size [400, 400] must be multiple of max stride 32, updating to [416, 416]
# image 1/20 /content/drive/MyDrive/yolov5/test_image/%e0%b9%81%e0%b8%ad%e0%b8%9b%e0%b9%80%e0%b8%9b%e0%b8%b4%e0%b9%89%e0%b8%a5.jpg: 288x416 12 apples, Done. (0.011s)
# ...
